# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import pyreadr
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from numpy import linalg as LA

# %% [markdown]
# ### Spreads

# %% [markdown]
# $\frac{dS^i}{S^i} = \sum_{l} \beta_{i,l} \frac{dI^l}{I^l} + \alpha_i + dZ^i$

# %%
df = pd.read_csv('data/sp500_data.csv')
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.set_index('date',inplace=True)

# %%
# 442 stock returns over 5 years - 1258 days
df.shape
# Out:
# (1259, 442)

# %%
# get rid of _price
col_list = []
for i in df.columns:
    col_list.append(i.split('_', 1)[0])
df.columns = col_list

# %%
df = df.pct_change()

# %%
df = df.dropna(axis=0)

# %%
df.index[-1]
# Out:
# '2019-10-04'

# %%
import glob

path = '/Users/zachariemartin/Desktop/School/Projects/summer2019/sum19/data/etf data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df_ = pd.read_csv(filename, usecols=[4], header='infer')
    li.append(df_)

etf_df = pd.concat(li, axis=1, ignore_index=True)

# %%
etf_df = etf_df.pct_change()
etf_df = etf_df.dropna(axis=0)

# %%
# 9 etf returns over 5 years - 1258 days

x = etf_df.values
x.shape
# Out:
# (1258, 9)

# %%
# throw out intercept

# %%
from sklearn import linear_model

# regress on each stocks returns, save residuals
reg = linear_model.LinearRegression(fit_intercept=False)
x = etf_df.values
df_residuals = pd.DataFrame(columns=df.columns)

for i in range(df.shape[1]):
    y = df.iloc[:,i].values.reshape(-1,1)
    reg.fit(x,y)
    w = reg.coef_
    b = reg.intercept_
    df_residuals.iloc[:,i] = (y-(x@w.T + b)).flatten()

# %%
# compare this cell and the one below
df_residuals.head()
# Out:
#        AAPL       ACN       AMG       AMT      ANTM      BBBY        BK  \
# 0  0.006154 -0.007869  0.006762 -0.000863  0.003066  0.015486 -0.005636
# 1  0.003695 -0.005921  0.001593  0.003315 -0.004218  0.001876 -0.000052
# 2  0.014483 -0.002763 -0.000345  0.008392  0.013893  0.019873 -0.010822
# 3  0.031347 -0.002469  0.000147  0.000180 -0.011363 -0.021116 -0.003570
# 4 -0.002215  0.006749 -0.004672 -0.007954  0.000460  0.001008 -0.003530
#
#         CAH        DE      DLTR  ...       MLM      MSFT      NFLX         O  \
# 0 -0.001046 -0.007980  0.011531  ... -0.002786  0.002844  0.003816 -0.001981
# 1  0.005139  0.001570 -0.002499  ... -0.009441  0.006164  0.001839  0.007510
# 2  0.005232  0.021588  0.009543  ...  0.002278 -0.003077  0.015848  0.026125
# 3  0.001655  0.016587 -0.014162  ... -0.020429 -0.011139  0.005169 -0.010419
# 4  0.004324  0.025657  0.009701  ... -0.016232  0.001532 -0.004094  0.008881
#
#        PCAR      SRCL      TGNA       TXT         V        WU
# 0  0.001481  0.006961  0.007732 -0.004447 -0.002629 -0.002995
# 1  0.017002 -0.002338 -0.009323 -0.003535  0.000568  0.005938
# 2  0.004183  0.012287 -0.016860 -0.005652 -0.003823 -0.012540
# 3  0.000114 -0.003311 -0.015888  0.009501  0.007079 -0.000620
# 4  0.004517  0.013349 -0.006884 -0.008634  0.009201  0.005154
#
# [5 rows x 442 columns]

# %%
# compare this cell and the one above
df_residuals = df_residuals.cumsum()
df_residuals.head()
# Out:
#        AAPL       ACN       AMG       AMT      ANTM      BBBY        BK  \
# 0  0.006154 -0.007869  0.006762 -0.000863  0.003066  0.015486 -0.005636
# 1  0.009849 -0.013791  0.008355  0.002453 -0.001152  0.017361 -0.005689
# 2  0.024332 -0.016553  0.008010  0.010845  0.012740  0.037234 -0.016510
# 3  0.055679 -0.019023  0.008157  0.011025  0.001377  0.016118 -0.020080
# 4  0.053464 -0.012273  0.003485  0.003070  0.001837  0.017126 -0.023611
#
#         CAH        DE      DLTR  ...       MLM      MSFT      NFLX         O  \
# 0 -0.001046 -0.007980  0.011531  ... -0.002786  0.002844  0.003816 -0.001981
# 1  0.004093 -0.006410  0.009033  ... -0.012227  0.009008  0.005655  0.005529
# 2  0.009325  0.015178  0.018575  ... -0.009949  0.005931  0.021503  0.031654
# 3  0.010980  0.031765  0.004413  ... -0.030378 -0.005208  0.026672  0.021235
# 4  0.015304  0.057422  0.014114  ... -0.046610 -0.003675  0.022577  0.030115
#
#        PCAR      SRCL      TGNA       TXT         V        WU
# 0  0.001481  0.006961  0.007732 -0.004447 -0.002629 -0.002995
# 1  0.018483  0.004623 -0.001590 -0.007982 -0.002061  0.002943
# 2  0.022665  0.016909 -0.018450 -0.013634 -0.005885 -0.009597
# 3  0.022780  0.013598 -0.034338 -0.004133  0.001195 -0.010217
# 4  0.027297  0.026947 -0.041223 -0.012767  0.010396 -0.005062
#
# [5 rows x 442 columns]

# %%
df_residuals.set_index(df.index,inplace=True)

# %%
df_residuals.to_csv('zprocess_data.csv')

# %%
from statsmodels.tsa.stattools import adfuller

df_df = pd.DataFrame(columns=['ADF Statistic','p-value','n lags used'],index=df_residuals.columns)

# test residuals for stationarity and return adf statistic and p-value, columns 0 and 1 respectively
for i in range(df_residuals.shape[1]):
    result = adfuller(df.iloc[:,i])
    df_df.iloc[i,0] = result[0]
    df_df.iloc[i,1] = result[1]
    df_df.iloc[i,2] = result[2]

# %%
# check for significance at 5%
np.where(df_df.iloc[:,1] > .05)
# Out:
# (array([], dtype=int64),)

# %%
df_df
# Out:
#       ADF Statistic      p-value n lags used
# AAPL       -10.8282  1.73499e-19           8
# ACN        -26.5612            0           1
# AMG        -34.0833            0           0
# AMT        -13.8091  8.29393e-26           8
# ANTM       -36.7231            0           0
# BBBY       -35.7298            0           0
# BK         -34.7934            0           0
# CAH         -36.784            0           0
# DE         -35.4293            0           0
# DLTR       -16.9549  9.40131e-30           3
# ETFC       -35.6518            0           0
# ETN        -18.4407  2.16132e-30           3
# FLS        -34.4618            0           0
# FMC        -34.7624            0           0
# FOSL       -35.0349            0           0
# INTU       -18.8436            0           3
# NAVI        -34.822            0           0
# NDAQ       -18.9383            0           3
# NLSN       -26.1485            0           1
# NOC        -15.5925  1.87252e-28           6
# NWSA       -35.9671            0           0
# PCG        -9.11736  3.27496e-15          16
# PFE        -33.8822            0           0
# PFG        -35.4372            0           0
# PRGO       -26.6934            0           1
# R          -25.8422            0           1
# ROP        -37.4574            0           0
# SBAC       -14.3979  8.60646e-27           8
# SCHW       -19.0064            0           2
# SWKS       -36.2174            0           0
# ...             ...          ...         ...
# ZTS        -39.1054            0           0
# ADM         -34.814            0           0
# AZO        -38.2355            0           0
# C          -34.6396            0           0
# CCI        -14.1462  2.20195e-26           8
# CME        -36.7317            0           0
# CMS        -13.2353  9.40577e-25           8
# DG         -26.7515            0           1
# DVA         -35.806            0           0
# ENDP       -18.9596            0           2
# EQIX       -19.7566            0           3
# FITB       -35.4763            0           0
# GOOGL      -14.7429  2.55468e-27           7
# HON        -37.2175            0           0
# IBM        -35.4749            0           0
# KSS         -36.776            0           0
# LBTYK      -14.2281  1.61413e-26           7
# LYB        -25.7994            0           1
# MA         -18.2076  2.39715e-30           4
# MDT        -19.4826            0           3
# MLM        -25.7288            0           1
# MSFT       -15.0298  9.94007e-28           7
# NFLX       -16.5437  1.97338e-29           4
# O          -35.3618            0           0
# PCAR       -36.4356            0           0
# SRCL       -36.1383            0           0
# TGNA       -10.4279  1.63931e-18          11
# TXT        -35.0726            0           0
# V          -18.2565  2.33637e-30           4
# WU         -26.4304            0           1
#
# [442 rows x 3 columns]

# %%
# plot R results
df_plot = pd.read_csv('data/mgarch_sim_3000_z100.csv')

# %%
num_days = df_plot.shape[0]

df_plot.set_index(pd.date_range('2019-10-05', periods=num_days),inplace=True)
df_plot.drop(['Unnamed: 0'],inplace=True,axis=1)

# plt.plot(datelist,df_plot[:,0])

# %%
df_plot.to_csv('mgarch_sim_3000_z100_1.csv')

# %% [markdown]
# ### Covariance Matrices

# %%
# this is what the real first cov matrix looks like from R
# cov_mats[1:5,1:5,1]
#               AAPL           ACN           AMG           AMT          ANTM
# AAPL  8.754898e-05 -1.139086e-05 -1.192942e-06 -1.746261e-06  6.700847e-06
# ACN  -1.139086e-05  5.723274e-05  1.643228e-06  8.624553e-06  9.799957e-07
# AMG  -1.192942e-06  1.643228e-06  1.206017e-04  6.715948e-06 -9.447320e-06
# AMT  -1.746261e-06  8.624553e-06  6.715948e-06  8.823275e-05 -3.082557e-06
# ANTM  6.700847e-06  9.799957e-07 -9.447320e-06 -3.082557e-06  1.224090e-04

# %%
covMats = np.load("data/mgarch_sim_3000_cov100.npy")

# %%
# load
# covMats = pd.read_csv('data/mgarch_sim_3000_cov100.csv')
covMats = np.load("data/mgarch_sim_3000_cov100.npy")
# shape
covMats.shape
# Out:
# (30000000,)

# %%
covM = np.reshape(covMats,(3000,100,100))

# %%
# ensure we are working with symmetric matrices

def check_symmetric(a, rtol=1e-05, atol=1e-08):
    return np.allclose(a, a.T, rtol=rtol, atol=atol)
for i in range(covM.shape[0]):
    if check_symmetric(covM[0,:,:]) == False:
        print(i)

# %%
# dimensions
n = 100

# lists
var55 = []
var95 = []
condNum = []

for i in range(covM.shape[0]):
    # sigma[i]
    mat = covM[i,:,:]
    
    # condition number
    c = LA.cond(mat)
    condNum.append(c)
    
    # perform svd decomp
    model = PCA(n_components=n)
    model.fit_transform(mat)
    
    # explained variance vector - cumulative
    v = model.explained_variance_ratio_.cumsum()
    idx55 = np.where(v>=.55)
    idx95 = np.where(v>=.95)
    
    # extract number of eigenvalues needed, 0 indexed 
    x = idx55[0][0] + 1
    y = idx95[0][0] + 1
    
    # append to list
    var55.append(x)
    var95.append(y)

# %%
# dates
dates = pd.date_range('2019-10-05', periods=num_days)

arr = np.zeros((covM.shape[0],3))
arr[:,0] = var55
arr[:,1] = var95
arr[:,2] = condNum

df = pd.DataFrame(arr)
df.index = df_plot.index
col_string = 'number of eigenvalues needed to explain '
df.columns = [col_string + '55% variance',col_string + '95% variance','condition number']

# num dates to plot to ease visualization
length = 500

for i in range(df.shape[1]):
        plt.figure(i,figsize=(20,10))
        plt.plot(dates[:length],df.iloc[:length,i])
        plt.xticks(df.iloc[:length,i].index[::50], rotation=30)
        plt.title(df.columns[i])
        plt.savefig('{}.png'.format(df.columns[i]))
        plt.show()

# %%
# %pwd
# Out:
# '/Users/zachariemartin/Desktop/School/Projects/summer2019/sum19'

# %%
# write array to csv
df.to_csv('mgarch_sim_3000_condnum.csv')
